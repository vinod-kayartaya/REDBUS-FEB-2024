# %%
import pandas as pd

data = pd.read_csv('datasets/olympics.csv', skiprows=4)

# %%
data.shape
# Out:
# (29215, 10)

# %%
pd.__version__
# Out:
# '2.2.0'

# %%
pd.show_versions()
# Out:
# INSTALLED VERSIONS
# ------------------
# commit                : fd3f57170aa1af588ba877e8e28c158a20a4886d
# python                : 3.12.0.final.0
# python-bits           : 64
# OS                    : Darwin
# OS-release            : 23.2.0
# Version               : Darwin Kernel Version 23.2.0: Wed Nov 15 21:54:10 PST 2023; root:xnu-10002.61.3~2/RELEASE_X86_64
# machine               : x86_64
# processor             : i386
# byteorder             : little
# LC_ALL                : None
# LANG                  : None
# LOCALE                : None.UTF-8
#
# pandas                : 2.2.0
# numpy                 : 1.26.4
# pytz                  : 2024.1
# dateutil              : 2.8.2
# setuptools            : None
# pip                   : 24.0
# Cython                : None
# pytest                : None
# hypothesis            : None
# sphinx                : None
# blosc                 : None
# feather               : None
# xlsxwriter            : None
# ...

# %%
data
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
data['City']
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
data.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
data.head(10)
# Out:
#      City  Edition     Sport Discipline                Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming       HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming      DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming     MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming     CHASAPIS, Spiridon  GRE    Men
# 5  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 6  Athens     1896  Aquatics   Swimming          HAJOS, Alfred  HUN    Men
# 7  Athens     1896  Aquatics   Swimming       ANDREOU, Joannis  GRE    Men
# 8  Athens     1896  Aquatics   Swimming  CHOROPHAS, Efstathios  GRE    Men
# 9  Athens     1896  Aquatics   Swimming          NEUMANN, Paul  AUT    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# ...

# %%
data.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %%
data[['City', 'Edition', 'Sport']]
# Out:
#           City  Edition      Sport
# 0       Athens     1896   Aquatics
# 1       Athens     1896   Aquatics
# 2       Athens     1896   Aquatics
# 3       Athens     1896   Aquatics
# 4       Athens     1896   Aquatics
# ...        ...      ...        ...
# 29211  Beijing     2008  Wrestling
# 29212  Beijing     2008  Wrestling
# 29213  Beijing     2008  Wrestling
# 29214  Beijing     2008  Wrestling
# 29215  Beijing     2008  Wrestling
#
# [29216 rows x 3 columns]

# %%
print(data.size)
print(data.shape)
# Out:
# 292160
# (29216, 10)

# %%
data.City
# Out:
# 0         Athens
# 1         Athens
# 2         Athens
# 3         Athens
# 4         Athens
#           ...
# 29211    Beijing
# 29212    Beijing
# 29213    Beijing
# 29214    Beijing
# 29215    Beijing
# Name: City, Length: 29216, dtype: object

# %%
data[data['City']=='Athens']
# Out:
#          City  Edition      Sport       Discipline               Athlete  NOC  \
# 0      Athens     1896   Aquatics         Swimming         HAJOS, Alfred  HUN
# 1      Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto  AUT
# 2      Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios  GRE
# 3      Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis  GRE
# 4      Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon  GRE
# ...       ...      ...        ...              ...                   ...  ...
# 27169  Athens     2004  Wrestling  Wrestling Gre-R  GABER IBRAHIM, Karam  EGY
# 27170  Athens     2004  Wrestling  Wrestling Gre-R        NOZADZE, Ramaz  GEO
# 27171  Athens     2004  Wrestling  Wrestling Gre-R        GARDNER, Rulon  USA
# 27172  Athens     2004  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
# 27173  Athens     2004  Wrestling  Wrestling Gre-R   TSURTSUMIA, Georgiy  KAZ
#
# ...

# %%
data[data.City=='Athens']
# Out:
#          City  Edition      Sport       Discipline               Athlete  NOC  \
# 0      Athens     1896   Aquatics         Swimming         HAJOS, Alfred  HUN
# 1      Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto  AUT
# 2      Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios  GRE
# 3      Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis  GRE
# 4      Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon  GRE
# ...       ...      ...        ...              ...                   ...  ...
# 27169  Athens     2004  Wrestling  Wrestling Gre-R  GABER IBRAHIM, Karam  EGY
# 27170  Athens     2004  Wrestling  Wrestling Gre-R        NOZADZE, Ramaz  GEO
# 27171  Athens     2004  Wrestling  Wrestling Gre-R        GARDNER, Rulon  USA
# 27172  Athens     2004  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
# 27173  Athens     2004  Wrestling  Wrestling Gre-R   TSURTSUMIA, Georgiy  KAZ
#
# ...

# %%
data['City']=='Athens'
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214    False
# 29215    False
# Name: City, Length: 29216, dtype: bool

# %%
data[data['Event']=='100m freestyle']
# Out:
#            City  Edition     Sport Discipline            Athlete  NOC Gender  \
# 0        Athens     1896  Aquatics   Swimming      HAJOS, Alfred  HUN    Men
# 1        Athens     1896  Aquatics   Swimming   HERSCHMANN, Otto  AUT    Men
# 673    St Louis     1904  Aquatics   Swimming    LEARY, J. Scott  USA    Men
# 674    St Louis     1904  Aquatics   Swimming     HALMAY, Zoltan  HUN    Men
# 675    St Louis     1904  Aquatics   Swimming   DANIELS, Charles  USA    Men
# ...         ...      ...       ...        ...                ...  ...    ...
# 27231   Beijing     2008  Aquatics   Swimming     BERNARD, Alain  FRA    Men
# 27232   Beijing     2008  Aquatics   Swimming    SULLIVAN, Eamon  AUS    Men
# 27233   Beijing     2008  Aquatics   Swimming  COUGHLIN, Natalie  USA  Women
# 27234   Beijing     2008  Aquatics   Swimming    STEFFEN, Britta  GER  Women
# 27235   Beijing     2008  Aquatics   Swimming  TRICKETT, Lisbeth  AUS  Women
#
#                 Event Event_gender   Medal
# ...

# %%
# data['Sport'].value_counts()
data.Gender.value_counts()
# Out:
# Gender
# Men      21721
# Women     7495
# Name: count, dtype: int64

# %%
data[data['Event']=='100m freestyle'][['Athlete', 'Gender', 'Medal']]
# Out:
#                  Athlete Gender   Medal
# 0          HAJOS, Alfred    Men    Gold
# 1       HERSCHMANN, Otto    Men  Silver
# 673      LEARY, J. Scott    Men  Bronze
# 674       HALMAY, Zoltan    Men    Gold
# 675     DANIELS, Charles    Men  Silver
# ...                  ...    ...     ...
# 27231     BERNARD, Alain    Men    Gold
# 27232    SULLIVAN, Eamon    Men  Silver
# 27233  COUGHLIN, Natalie  Women  Bronze
# 27234    STEFFEN, Britta  Women    Gold
# 27235  TRICKETT, Lisbeth  Women  Silver
#
# [142 rows x 3 columns]

# %%
data[data['Event']=='100m freestyle']['Athlete']
# Out:
# 0            HAJOS, Alfred
# 1         HERSCHMANN, Otto
# 673        LEARY, J. Scott
# 674         HALMAY, Zoltan
# 675       DANIELS, Charles
#                ...
# 27231       BERNARD, Alain
# 27232      SULLIVAN, Eamon
# 27233    COUGHLIN, Natalie
# 27234      STEFFEN, Britta
# 27235    TRICKETT, Lisbeth
# Name: Athlete, Length: 142, dtype: object

# %%
data['Athlete'].sort_values()
# Out:
# 651                 AABYE, Edgar
# 2849       AALTONEN, Arvo Ossian
# 2852       AALTONEN, Arvo Ossian
# 7716    AALTONEN, Paavo Johannes
# 7730    AALTONEN, Paavo Johannes
#                   ...
# 603                   ÖSTMO, Ole
# 608                   ÖSTMO, Ole
# 621                   ÖSTMO, Ole
# 596                   ÖSTMO, Ole
# 8051           ÖSTRAND, Per-Olof
# Name: Athlete, Length: 29216, dtype: object

# %%
data.sort_values(by='Edition', ascending=False)
# Out:
#           City  Edition       Sport       Discipline               Athlete  \
# 29215  Beijing     2008   Wrestling  Wrestling Gre-R        BAROEV, Khasan
# 27859  Beijing     2008  Basketball       Basketball     LISINA, Ekaterina
# 27846  Beijing     2008  Basketball       Basketball            GASOL, Pau
# 27847  Beijing     2008  Basketball       Basketball       JIMENEZ, Carlos
# 27848  Beijing     2008  Basketball       Basketball           LOPEZ, Raul
# ...        ...      ...         ...              ...                   ...
# 101     Athens     1896  Gymnastics      Artistic G.  FLATOW, Gustav Felix
# 100     Athens     1896  Gymnastics      Artistic G.        FLATOW, Alfred
# 99      Athens     1896  Gymnastics      Artistic G.        BÖCKER, Konrad
# 98      Athens     1896  Gymnastics      Artistic G.  MITROPOULOS, Ioannis
# 0       Athens     1896    Aquatics         Swimming         HAJOS, Alfred
#
#        NOC Gender                Event Event_gender   Medal
# ...

# %%
data.sort_values(by=['Edition', 'Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %%
data.sort_values(by=['Edition', 'Athlete'], ascending=[False, True])
# Out:
#           City  Edition          Sport       Discipline              Athlete  \
# 28460  Beijing     2008       Handball         Handball     AAMODT, Ragnhild
# 28134  Beijing     2008        Fencing          Fencing     ABAJO, Jose Luis
# 27691  Beijing     2008      Athletics        Athletics     ABAKUMOVA, Maria
# 27983  Beijing     2008  Canoe / Kayak  Canoe / Kayak F  ABALMASAU, Aliaksei
# 28417  Beijing     2008       Handball         Handball           ABALO, Luc
# ...        ...      ...            ...              ...                  ...
# 83      Athens     1896     Gymnastics      Artistic G.   XENAKIS, Thomasios
# 113     Athens     1896     Gymnastics      Artistic G.   XENAKIS, Thomasios
# 75      Athens     1896     Gymnastics      Artistic G.        ZUTTER, Louis
# 76      Athens     1896     Gymnastics      Artistic G.        ZUTTER, Louis
# 116     Athens     1896     Gymnastics      Artistic G.        ZUTTER, Louis
#
# ...

# %%
data[(data['Event']=='100m freestyle') & (data['Gender']=='Women')]
# Out:
#             City  Edition     Sport Discipline             Athlete  NOC  \
# 1955   Stockholm     1912  Aquatics   Swimming    FLETCHER, Jennie  GBR
# 1956   Stockholm     1912  Aquatics   Swimming       DURACK, Fanny  ANZ
# 1957   Stockholm     1912  Aquatics   Swimming   WYLIE, Wilhelmina  ANZ
# 2843     Antwerp     1920  Aquatics   Swimming    SCHROTH, Frances  USA
# 2844     Antwerp     1920  Aquatics   Swimming  BLEIBTREY, Ethelda  USA
# ...          ...      ...       ...        ...                 ...  ...
# 25234     Athens     2004  Aquatics   Swimming        HENRY, Jodie  AUS
# 25235     Athens     2004  Aquatics   Swimming     DE BRUIJN, Inge  NED
# 27233    Beijing     2008  Aquatics   Swimming   COUGHLIN, Natalie  USA
# 27234    Beijing     2008  Aquatics   Swimming     STEFFEN, Britta  GER
# 27235    Beijing     2008  Aquatics   Swimming   TRICKETT, Lisbeth  AUS
#
#       Gender           Event Event_gender   Medal
# 1955   Women  100m freestyle            W  Bronze
# ...

# %%
data[(data['Event']=='100m freestyle') & (data['Gender']=='Women') & (data['Medal']=='Gold')]
# Out:
#                         City  Edition     Sport Discipline  \
# 1956               Stockholm     1912  Aquatics   Swimming
# 2844                 Antwerp     1920  Aquatics   Swimming
# 4145                   Paris     1924  Aquatics   Swimming
# 5026               Amsterdam     1928  Aquatics   Swimming
# 5736             Los Angeles     1932  Aquatics   Swimming
# 6351                  Berlin     1936  Aquatics   Swimming
# 7226                  London     1948  Aquatics   Swimming
# 8040                Helsinki     1952  Aquatics   Swimming
# 8932   Melbourne / Stockholm     1956  Aquatics   Swimming
# 9817                    Rome     1960  Aquatics   Swimming
# 10696                  Tokyo     1964  Aquatics   Swimming
# 11718                 Mexico     1968  Aquatics   Swimming
# 12749                 Munich     1972  Aquatics   Swimming
# 13934               Montreal     1976  Aquatics   Swimming
# 15239                 Moscow     1980  Aquatics   Swimming
# ...

# %%
data[(data['Event']=='100m freestyle') & (data['Gender']=='Women') & (data['Medal']=='Gold')].shape
# Out:
# (23, 10)

# %%
data.info
# Out:
# <bound method DataFrame.info of           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
# ...

# %%
data.describe()
# Out:
#             Edition
# count  29216.000000
# mean    1967.713171
# std       32.406293
# min     1896.000000
# 25%     1948.000000
# 50%     1976.000000
# 75%     1996.000000
# max     2008.000000

# %%
data.groupby('City').count()
# Out:
#                        Edition  Sport  Discipline  Athlete   NOC  Gender  \
# City
# Amsterdam                  710    710         710      710   710     710
# Antwerp                   1298   1298        1298     1298  1298    1298
# Athens                    2149   2149        2149     2149  2149    2149
# Atlanta                   1859   1859        1859     1859  1859    1859
# Barcelona                 1705   1705        1705     1705  1705    1705
# Beijing                   2042   2042        2042     2042  2042    2042
# Berlin                     875    875         875      875   875     875
# Helsinki                   889    889         889      889   889     889
# London                    1618   1618        1618     1618  1618    1618
# Los Angeles               2074   2074        2074     2074  2074    2074
# Melbourne / Stockholm      885    885         885      885   885     885
# Mexico                    1031   1031        1031     1031  1031    1031
# ...

# %%
data.City.value_counts()
# Out:
# City
# Athens                   2149
# Los Angeles              2074
# Beijing                  2042
# Sydney                   2015
# Atlanta                  1859
# Barcelona                1705
# London                   1618
# Seoul                    1546
# Paris                    1396
# Moscow                   1387
# Montreal                 1305
# Antwerp                  1298
# Munich                   1185
# Mexico                   1031
# Tokyo                    1010
# Helsinki                  889
# Stockholm                 885
# Melbourne / Stockholm     885
# Rome                      882
# Berlin                    875
# Amsterdam                 710
# St Louis                  470
# Name: count, dtype: int64

# %%
groupby_city = data.groupby('City')

# %%
dir(groupby_city)
# Out:
# ['Athlete',
#  'City',
#  'Discipline',
#  'Edition',
#  'Event',
#  'Event_gender',
#  'Gender',
#  'Medal',
#  'NOC',
#  'Sport',
#  '_DataFrameGroupBy__examples_dataframe_doc',
#  '__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_accessors',
#  '_agg_examples_doc',
#  '_agg_general',
#  '_agg_py_fallback',
#  '_aggregate_frame',
#  '_aggregate_with_numba',
#  '_apply_filter',
#  '_apply_to_column_groupbys',
#  '_ascending_count',
# ...

# %%
groupby_city['Medal'].count()
# Out:
# City
# Amsterdam                 710
# Antwerp                  1298
# Athens                   2149
# Atlanta                  1859
# Barcelona                1705
# Beijing                  2042
# Berlin                    875
# Helsinki                  889
# London                   1618
# Los Angeles              2074
# Melbourne / Stockholm     885
# Mexico                   1031
# Montreal                 1305
# Moscow                   1387
# Munich                   1185
# Paris                    1396
# Rome                      882
# Seoul                    1546
# St Louis                  470
# Stockholm                 885
# Sydney                   2015
# Tokyo                    1010
# Name: Medal, dtype: int64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data['City'].value_counts().plot()
# Out:
# <Axes: xlabel='City'>

# %%
data['City'].value_counts().plot(kind='barh', color='#ababab')
# Out:
# <Axes: ylabel='City'>

# %%
data['Sport'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
data
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
data[data.Athlete.str.contains('Singh')]
# Out:
#               City  Edition   Sport Discipline               Athlete  NOC  \
# 6123   Los Angeles     1932  Hockey     Hockey      BAIS, Roop Singh  IND
# 6964        Berlin     1936  Hockey     Hockey      BAIS, Roop Singh  IND
# 16088       Moscow     1980  Hockey     Hockey   AMARJIT RANA, Singh  IND
# 16091       Moscow     1980  Hockey     Hockey      DEAVINDER, Singh  IND
# 16093       Moscow     1980  Hockey     Hockey        GURMAIL, Singh  IND
# 16098       Moscow     1980  Hockey     Hockey          SINGH, Singh  IND
# 16099       Moscow     1980  Hockey     Hockey          SINGH, Singh  IND
# 16100       Moscow     1980  Hockey     Hockey       SURINDER, Singh  IND
# 17517  Los Angeles     1984  Hockey     Hockey  BHAURA, Kulbir Singh  GBR
# 19032        Seoul     1988  Hockey     Hockey  BHAURA, Kulbir Singh  GBR
#
#       Gender   Event Event_gender   Medal
# 6123     Men  hockey            M    Gold
# 6964     Men  hockey            M    Gold
# ...

# %%
data[data['Athlete'].str.startswith('BOLT')]
# Out:
#                         City  Edition       Sport  Discipline  \
# 2159               Stockholm     1912  Equestrian    Dressage
# 5985             Los Angeles     1932  Equestrian    Dressage
# 7560                  London     1948  Equestrian    Dressage
# 8400                Helsinki     1952  Equestrian    Dressage
# 9290   Melbourne / Stockholm     1956  Equestrian    Dressage
# 21901                Atlanta     1996  Basketball  Basketball
# 23842                 Sydney     2000  Basketball  Basketball
# 27552                Beijing     2008   Athletics   Athletics
# 27570                Beijing     2008   Athletics   Athletics
# 27603                Beijing     2008   Athletics   Athletics
#
#                              Athlete  NOC Gender         Event Event_gender  \
# 2159       BOLTENSTERN, Gustaf-Adolf  SWE    Men    individual            X
# 5985   BOLTENSTERN JR., Gustaf Adolf  SWE    Men          team            X
# ...

# %%
data.shape
# Out:
# (29216, 10)

# %%
data['MedalCode'] = data.Medal.str.upper()

# %%
data.shape
# Out:
# (29216, 11)

# %%
data
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal MedalCode
# ...

# %%
data[data['Edition'] > 2000]
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 25176   Athens     2004   Aquatics           Diving           TIAN, Liang
# 25177   Athens     2004   Aquatics           Diving               HU, Jia
# 25178   Athens     2004   Aquatics           Diving          HELM, Mathew
# 25179   Athens     2004   Aquatics           Diving         TOURKY, Loudy
# 25180   Athens     2004   Aquatics           Diving    NEWBERY, Chantelle
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender         Event Event_gender   Medal MedalCode
# ...
